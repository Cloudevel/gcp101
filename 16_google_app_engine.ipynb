# %% [markdown]
# [![cloudevel](img/cloudevel.png)](https://cloudevel.com)

# %% [markdown]
# # *Google App Engine*.

# %% [markdown]
# Es un servicio de *Google Cloud Platform* que permite desplegar una aplicación dentro de de la plataforma, la cual es totalmente autogestionada.
#
# Este tipo de servicios se recomiendan cuando un proyecto requiere desplegar una sola aplicación, debido a que sólamente es posible correr una *app* en un servicio.

# %% [markdown]
# ```
# gcloud app <argumantos>
# ```

# %% [markdown]
# ## Tipos de entornos.

# %% [markdown]
# ### Entorno estándar.
#
#
# Permite ejecutar aplicaciones escritas en los lenguajes soportados por *CGP*.
#
#
# * Python 3.x
# * Java 8 y 11
# * PHP 5 y7
# * Ruby
# * Go 1.11 y 1.12+
# * Node.js
#
#
# https://cloud.google.com/appengine/docs/standard

# %% [markdown]
# ### Entorno flexible.
#
# Permite crear aplicaciones dentro de un contenedor de Docker, el cual será ejecutado desde *GCP* y -a diferencia de la versión estándar- es posible acceder a las instancias mediante *ssh*.
#
# https://cloud.google.com/appengine/docs/flexible/custom-runtimes/quickstart

# %% [markdown]
# ## Componentes.

# %% [markdown]
# * Aplicaciones.
# * Servicios.
# * Versiones.
# * Instancias.
#
# https://cloud.google.com/appengine/docs/standard/python3/an-overview-of-app-engine

# %% [markdown]
#  ## El dominio ```appspot.com```.
#
# Cuando se despliega una aplicación, la raíz de dicha aplicación será publicada como un subdominio del dominio ```appspot.com```.

# %% [markdown]
# ## Tipos de implementaciones.
#
# *Google* ha publiado un repositorio con código de ejemplo para gran parte de sus productos, el cual puede ser consultado desde:
#
# https://github.com/GoogleCloudPlatform
#
# En este caso, se estudiará un ejemplo de *Google App Engine* estándar con *Python 3* basada en el código localizado en:
#
# https://github.com/GoogleCloudPlatform/python-docs-samples/tree/master/appengine/standard_python3/hello_world

# %% [markdown]
# ### Instalación de *Google App Engine* para *Python*.

# %% [markdown]
# ```
# gcloud components install app-engine-python
# ```

# %% [markdown]
# ```
# git clone https://github.com/GoogleCloudPlatform/python-docs-samples
# ```

# %% [markdown]
# ## *Scripts* de configuración de *App Engine*.
#
# Es posible definir el comportamiento de *App Engine* mediante los siguientes *scripts*
#
#
# https://cloud.google.com/appengine/docs/standard/python3/configuration-files
# * [```app.yaml```](https://cloud.google.com/appengine/docs/standard/python/config/appref). El cual especifica la forma en la que se gestionarán las *URLs* y otras configuraciones adicionales.
# * [```dispatch.yaml```](https://cloud.google.com/appengine/docs/standard/python3/reference/dispatch-yaml). El cual permite definir rutas para más de un servicio. Cada servicio tendrá su propio script ```app.yaml```. En caso de que no exista este archivo, el servicio por defecto es ```default```.
# * [```cron.yaml```](https://cloud.google.com/appengine/docs/standard/python3/config/cronref). El cual perimite realizar operaciones programadas.
# * [```index.yaml```](https://cloud.google.com/appengine/docs/standard/python3/config/indexref). El cual puede configurar índices de *Datastore*.

# %% [markdown]
# ### Contenidos de ```app.yaml```.
#
# * La descripción del entorno de ejecución (*runtime*) con el que se ejecutará el servicio.
# * Las rutas a las que accederá el servicio.
# * El escalamiento de los servicios.

# %% [markdown]
# ## Gestión de una aplicación.

# %% [markdown]
# ### Creación de una *app*.
#
# ```
# gcloud app-create --region <región>
# ```

# %%
gcloud app create --region us-central

# %% [markdown]
# ### Descripción de una *app*.
#
# ```
# gcloud app describe
# ```

# %%
gcloud app describe

# %% [markdown]
# ### Despliegue de una *app*.

# %% [markdown]
# Para desplegar una aplicación se ejecuta el siguiente comando:
# ```
# gcloud app deploy <script> <argumentos>
# ```
#
# Donde:
#
# * ```<script>``` es un script de *YAML* como ```app.yaml``` o ```dispatch.yaml```.
#
# Algunos argumentos adicionales son:
#
# * ```--version```
# * ```--project```
# * ```--no-promote```

# %%
cd /home/josech/Codigo/Pythonista/Cursos/py-221-aux/proyecto_seguro/abc_alumnos
# Out:
# : 1

# %%
ls
# Out:
# app.yaml       data     models.py         schemas.py   venv
# auth           env.sh   __pycache__       settings.py
# blueprints.py  main.py  requirements.txt  static
# : 1

# %%
gcloud app deploy app.yaml --quiet
# Out:
# Services to deploy:
#
# descriptor:                  [/home/josech/Dropbox/Codigo/Pythonista/Cursos/py-221-aux/proyecto_seguro/abc_alumnos/app.yaml]
# source:                      [/home/josech/Dropbox/Codigo/Pythonista/Cursos/py-221-aux/proyecto_seguro/abc_alumnos]
# target project:              [tercera-generacion]
# target service:              [default]
# target version:              [20211124t182948]
# target url:                  [https://tercera-generacion.ue.r.appspot.com]
# target service account:      [App Engine default service account]
#
#
# Beginning deployment of service [default]...
# ╔════════════════════════════════════════════════════════════╗
# ╠═ Uploading 0 files to Google Cloud Storage                ═╣
# ╚════════════════════════════════════════════════════════════╝
# File upload done.
# Updating service [default]...done.
# Setting traffic split for service [default]...done.
# Deployed service [default] to [https://tercera-generacion.ue.r.appspot.com]
#
# You can stream logs from the command line by running:
#   $ gcloud app logs tail -s default
#
# To view your application in the web browser run:
#   $ gcloud app browse
# : 1

# %% [markdown]
# ### Navegación hacia la aplicación.

# %% [markdown]
# ```
# glcoud app browse
# ```

# %% [markdown]
# ## Gestión de servicios.

# %% [markdown]
# ```
# gcloud app services
# ```
#
# https://cloud.google.com/sdk/gcloud/reference/app/services

# %%
gcloud app services list
# Out:
# SERVICE  NUM_VERSIONS
# default  3
# : 1

# %%
gcloud app services describe default
# Out:
# id: default
# name: apps/tercera-generacion/services/default
# split:
#   allocations:
#     20211124t182948: 1.0
# : 1

# %% [markdown]
# ## Gestión de versiones.

# %% [markdown]
# ```
# gcloud app versions <argumentos>
# ```
#
# https://cloud.google.com/sdk/gcloud/reference/app/versions

# %%
gcloud app versions list
# Out:
# SERVICE  VERSION.ID       TRAFFIC_SPLIT  LAST_DEPLOYED              SERVING_STATUS
# default  20211122t191234  0.00           2021-11-22T19:13:52-06:00  SERVING
# default  20211124t171353  0.00           2021-11-24T17:15:35-06:00  SERVING
# default  20211124t182948  0.00           2021-11-24T18:30:57-06:00  SERVING
# default  20211124t185338  1.00           2021-11-24T18:54:55-06:00  SERVING
# : 1

# %%
gcloud app versions describe 20211124t182948 --service default
# Out:
# createTime: '2021-11-25T00:30:57Z'
# createdBy: jlchiquete@syesoftware.com
# deployment:
#   files:
#     .ipynb_checkpoints/Untitled-checkpoint.ipynb:
#       sha1Sum: 87e64271eafadd1ae9246d9bc3020b4b8f7255d3
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/87e64271eafadd1ae9246d9bc3020b4b8f7255d3
#     app.yaml:
#       sha1Sum: 857880f487f2459a231f77518c7709f8dad8f79c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/857880f487f2459a231f77518c7709f8dad8f79c
#     auth/__init__.py:
#       sha1Sum: 868140b5d8441d7706241ef3dc9798f08fe8e909
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/868140b5d8441d7706241ef3dc9798f08fe8e909
#     auth/blueprints.py:
#       sha1Sum: 0a6c2b8a7eb0e52d69027029d645504c005c3814
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0a6c2b8a7eb0e52d69027029d645504c005c3814
#     auth/schemas.py:
#       sha1Sum: 6c0e2c6188c05a2c2ac26b8796e4a480f49b4121
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6c0e2c6188c05a2c2ac26b8796e4a480f49b4121
#     blueprints.py:
#       sha1Sum: 6f5074dc2c702446fae4c7ef14cbbc5d859073a3
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6f5074dc2c702446fae4c7ef14cbbc5d859073a3
#     data/__init__.py:
#       sha1Sum: ea3a2be7d9935fbcf2c53e9d074ea5126c9b4e0c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ea3a2be7d9935fbcf2c53e9d074ea5126c9b4e0c
#     data/alumnos.txt:
#       sha1Sum: 71696fddc249d228ba2829124c2b1d0a36ce6abc
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/71696fddc249d228ba2829124c2b1d0a36ce6abc
#     env.sh:
#       sha1Sum: 175fed4290c9aea87538a4ec2e4c49bf9803b8e5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/175fed4290c9aea87538a4ec2e4c49bf9803b8e5
#     main.py:
#       sha1Sum: d43df38b928629cc6209a6bf9c077199d34ad66a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d43df38b928629cc6209a6bf9c077199d34ad66a
#     models.py:
#       sha1Sum: 8e6dc577de5cccd1e50b9d33895ff0bff08425bf
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/8e6dc577de5cccd1e50b9d33895ff0bff08425bf
#     requirements.txt:
#       sha1Sum: 43e18e204ae97a0a9a0ea37650eaeb88094b4bfb
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/43e18e204ae97a0a9a0ea37650eaeb88094b4bfb
#     schemas.py:
#       sha1Sum: ca4463feebb0a40a65b3646f1d1175ac3cd89e23
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ca4463feebb0a40a65b3646f1d1175ac3cd89e23
#     settings.py:
#       sha1Sum: 7ecbc92a803a299e85e9670ce32a817daac8e8f5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/7ecbc92a803a299e85e9670ce32a817daac8e8f5
#     venv/bin/activate:
#       sha1Sum: fa778994c1a14acc97f668115acf673b05c34eaf
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/fa778994c1a14acc97f668115acf673b05c34eaf
#     venv/bin/activate.csh:
#       sha1Sum: 426dee0f13dec08fb4857b5afbc0a265ede91ac5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/426dee0f13dec08fb4857b5afbc0a265ede91ac5
#     venv/bin/activate.fish:
#       sha1Sum: fcc18c186415ac87f1d1161eb11c538cc4280c24
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/fcc18c186415ac87f1d1161eb11c538cc4280c24
#     venv/bin/activate.ps1:
#       sha1Sum: 4dba44b74fa882d43b03f43c112330140963f1f4
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/4dba44b74fa882d43b03f43c112330140963f1f4
#     venv/bin/activate.xsh:
#       sha1Sum: 54e58ecc64f0acf435e3f8d0fc3fb0a8398aaf98
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/54e58ecc64f0acf435e3f8d0fc3fb0a8398aaf98
#     venv/bin/activate_this.py:
#       sha1Sum: 908eda5c1c854ac3602a93a3cbba7bf9db4878ff
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/908eda5c1c854ac3602a93a3cbba7bf9db4878ff
#     venv/bin/email_validator:
#       sha1Sum: 1cdd71f19cd52912694f467b71f3a49956d6dfb6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1cdd71f19cd52912694f467b71f3a49956d6dfb6
#     venv/bin/flask:
#       sha1Sum: 40a3dc4b1a7672a09cddcac569e8048bb73eb1b6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40a3dc4b1a7672a09cddcac569e8048bb73eb1b6
#     venv/bin/pip:
#       sha1Sum: 1ffe4af855c7a33da5b7d5d3bad0fe82e458eeac
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1ffe4af855c7a33da5b7d5d3bad0fe82e458eeac
#     venv/bin/pip-3.9:
#       sha1Sum: 1ffe4af855c7a33da5b7d5d3bad0fe82e458eeac
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1ffe4af855c7a33da5b7d5d3bad0fe82e458eeac
#     venv/bin/pip3:
#       sha1Sum: 1ffe4af855c7a33da5b7d5d3bad0fe82e458eeac
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1ffe4af855c7a33da5b7d5d3bad0fe82e458eeac
#     venv/bin/pip3.9:
#       sha1Sum: 1ffe4af855c7a33da5b7d5d3bad0fe82e458eeac
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1ffe4af855c7a33da5b7d5d3bad0fe82e458eeac
#     venv/bin/python:
#       sha1Sum: 31f21d390ad65a679ca92910d3225fc373833558
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/31f21d390ad65a679ca92910d3225fc373833558
#     venv/bin/python3:
#       sha1Sum: 31f21d390ad65a679ca92910d3225fc373833558
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/31f21d390ad65a679ca92910d3225fc373833558
#     venv/bin/python3.9:
#       sha1Sum: 31f21d390ad65a679ca92910d3225fc373833558
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/31f21d390ad65a679ca92910d3225fc373833558
#     venv/bin/wheel:
#       sha1Sum: 1c818fdce55138183204aabfaeb73dd0e4171c43
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1c818fdce55138183204aabfaeb73dd0e4171c43
#     venv/bin/wheel-3.9:
#       sha1Sum: 1c818fdce55138183204aabfaeb73dd0e4171c43
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1c818fdce55138183204aabfaeb73dd0e4171c43
#     venv/bin/wheel3:
#       sha1Sum: 1c818fdce55138183204aabfaeb73dd0e4171c43
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1c818fdce55138183204aabfaeb73dd0e4171c43
#     venv/bin/wheel3.9:
#       sha1Sum: 1c818fdce55138183204aabfaeb73dd0e4171c43
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1c818fdce55138183204aabfaeb73dd0e4171c43
#     venv/include/site/python3.9/greenlet/greenlet.h:
#       sha1Sum: 21d2711d63698a938ae8a70f2bcb891bedd7d0f3
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/21d2711d63698a938ae8a70f2bcb891bedd7d0f3
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/LICENSE:
#       sha1Sum: 81abf2d5e72263d8fea973672da3ab75f8b31242
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/81abf2d5e72263d8fea973672da3ab75f8b31242
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/METADATA:
#       sha1Sum: 928e50b549b7a40f35de343d57a93216448c5b2b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/928e50b549b7a40f35de343d57a93216448c5b2b
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/NOTICE:
#       sha1Sum: b82589052d9e26333e8d90afb518ec59a922cbf9
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/b82589052d9e26333e8d90afb518ec59a922cbf9
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/RECORD:
#       sha1Sum: 7eb50b429963ea9d3fe0218e410c1e1a300daa19
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/7eb50b429963ea9d3fe0218e410c1e1a300daa19
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/REQUESTED:
#       sha1Sum: da39a3ee5e6b4b0d3255bfef95601890afd80709
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da39a3ee5e6b4b0d3255bfef95601890afd80709
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/WHEEL:
#       sha1Sum: 249fdb01ad3e3f71356e33e1897d06f23cfb20c2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/249fdb01ad3e3f71356e33e1897d06f23cfb20c2
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/entry_points.txt:
#       sha1Sum: 6e9f30e1322179f30449af19ed391382db59eb65
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6e9f30e1322179f30449af19ed391382db59eb65
#     venv/lib/python3.9/site-packages/APIFlask-0.10.0.dist-info/top_level.txt:
#       sha1Sum: 3610aed234d21f2389810b41a5e89141dc382106
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/3610aed234d21f2389810b41a5e89141dc382106
#     venv/lib/python3.9/site-packages/Flask-2.0.2.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Flask-2.0.2.dist-info/LICENSE.rst:
#       sha1Sum: e32a549b135c4b2b268107adc12d13cca2ca1e8c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e32a549b135c4b2b268107adc12d13cca2ca1e8c
#     venv/lib/python3.9/site-packages/Flask-2.0.2.dist-info/METADATA:
#       sha1Sum: be17b6e4ebcc5e66a78cf3f567cfbbd35ee4fa5a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/be17b6e4ebcc5e66a78cf3f567cfbbd35ee4fa5a
#     venv/lib/python3.9/site-packages/Flask-2.0.2.dist-info/RECORD:
#       sha1Sum: dec2c1d4c84687c2c6c679d93aa9069fde15fbcc
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/dec2c1d4c84687c2c6c679d93aa9069fde15fbcc
#     venv/lib/python3.9/site-packages/Flask-2.0.2.dist-info/WHEEL:
#       sha1Sum: 40a2b8d62232140e022876da90b2c784970b715b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40a2b8d62232140e022876da90b2c784970b715b
#     venv/lib/python3.9/site-packages/Flask-2.0.2.dist-info/entry_points.txt:
#       sha1Sum: 861b25b29756a87253c45ca8e60361a1136e8cf2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/861b25b29756a87253c45ca8e60361a1136e8cf2
#     venv/lib/python3.9/site-packages/Flask-2.0.2.dist-info/top_level.txt:
#       sha1Sum: e5b453f464d2b64fec735f6f6b12c94c21cae5f2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e5b453f464d2b64fec735f6f6b12c94c21cae5f2
#     venv/lib/python3.9/site-packages/Flask_HTTPAuth-4.5.0.dist-info/AUTHORS:
#       sha1Sum: 5d8c8959d13346abfb572bce874e2fd5f8d38ab6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5d8c8959d13346abfb572bce874e2fd5f8d38ab6
#     venv/lib/python3.9/site-packages/Flask_HTTPAuth-4.5.0.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Flask_HTTPAuth-4.5.0.dist-info/LICENSE:
#       sha1Sum: aae77e8b1f7dfa625dcc1156695b0e43e549c7b8
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/aae77e8b1f7dfa625dcc1156695b0e43e549c7b8
#     venv/lib/python3.9/site-packages/Flask_HTTPAuth-4.5.0.dist-info/METADATA:
#       sha1Sum: 484c8aa33e6d0175d6feb720b7b95bdb9cad6e59
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/484c8aa33e6d0175d6feb720b7b95bdb9cad6e59
#     venv/lib/python3.9/site-packages/Flask_HTTPAuth-4.5.0.dist-info/RECORD:
#       sha1Sum: ab81e7f39f1a18cc784238aab68e21a15844abb8
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ab81e7f39f1a18cc784238aab68e21a15844abb8
#     venv/lib/python3.9/site-packages/Flask_HTTPAuth-4.5.0.dist-info/WHEEL:
#       sha1Sum: 40a2b8d62232140e022876da90b2c784970b715b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40a2b8d62232140e022876da90b2c784970b715b
#     venv/lib/python3.9/site-packages/Flask_HTTPAuth-4.5.0.dist-info/top_level.txt:
#       sha1Sum: 07c613a199758a25664136c0104a51ff7f578385
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/07c613a199758a25664136c0104a51ff7f578385
#     venv/lib/python3.9/site-packages/Flask_Login-0.5.0.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Flask_Login-0.5.0.dist-info/LICENSE:
#       sha1Sum: 13142dd1618de525fa7f80597005fd666c5fd1ac
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/13142dd1618de525fa7f80597005fd666c5fd1ac
#     venv/lib/python3.9/site-packages/Flask_Login-0.5.0.dist-info/METADATA:
#       sha1Sum: 186d7a10df2583bff74ea637ba5e947f180ecea6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/186d7a10df2583bff74ea637ba5e947f180ecea6
#     venv/lib/python3.9/site-packages/Flask_Login-0.5.0.dist-info/RECORD:
#       sha1Sum: 0dc8c03018d4b03fd7a71703c11fcad16150ab2f
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0dc8c03018d4b03fd7a71703c11fcad16150ab2f
#     venv/lib/python3.9/site-packages/Flask_Login-0.5.0.dist-info/WHEEL:
#       sha1Sum: 5132cb7d835d40a81d25a4a1d85667eb13e1a4d3
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5132cb7d835d40a81d25a4a1d85667eb13e1a4d3
#     venv/lib/python3.9/site-packages/Flask_Login-0.5.0.dist-info/top_level.txt:
#       sha1Sum: 12065a1d4f0823b65d1794671bed652e4b4eaa68
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/12065a1d4f0823b65d1794671bed652e4b4eaa68
#     venv/lib/python3.9/site-packages/Flask_Mail-0.9.1.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Flask_Mail-0.9.1.dist-info/LICENSE:
#       sha1Sum: 3a89c34d6335e81f4ba6a7b58d8830cbac6a5232
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/3a89c34d6335e81f4ba6a7b58d8830cbac6a5232
#     venv/lib/python3.9/site-packages/Flask_Mail-0.9.1.dist-info/METADATA:
#       sha1Sum: a586182ae53907887136e0ce6127c93cb5976a2e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/a586182ae53907887136e0ce6127c93cb5976a2e
#     venv/lib/python3.9/site-packages/Flask_Mail-0.9.1.dist-info/RECORD:
#       sha1Sum: ddc8b6f1218239c554e9cb9e89dff68aa849c63d
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ddc8b6f1218239c554e9cb9e89dff68aa849c63d
#     venv/lib/python3.9/site-packages/Flask_Mail-0.9.1.dist-info/WHEEL:
#       sha1Sum: 249fdb01ad3e3f71356e33e1897d06f23cfb20c2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/249fdb01ad3e3f71356e33e1897d06f23cfb20c2
#     venv/lib/python3.9/site-packages/Flask_Mail-0.9.1.dist-info/top_level.txt:
#       sha1Sum: 52ca01f3fac35c36d9ee4d59394dee0a0ca60a86
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/52ca01f3fac35c36d9ee4d59394dee0a0ca60a86
#     venv/lib/python3.9/site-packages/Flask_SQLAlchemy-2.5.1.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Flask_SQLAlchemy-2.5.1.dist-info/LICENSE.rst:
#       sha1Sum: e32a549b135c4b2b268107adc12d13cca2ca1e8c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e32a549b135c4b2b268107adc12d13cca2ca1e8c
#     venv/lib/python3.9/site-packages/Flask_SQLAlchemy-2.5.1.dist-info/METADATA:
#       sha1Sum: 63bc556c48e7b84fd2da7e07cdafd2bdbbc82ecc
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/63bc556c48e7b84fd2da7e07cdafd2bdbbc82ecc
#     venv/lib/python3.9/site-packages/Flask_SQLAlchemy-2.5.1.dist-info/RECORD:
#       sha1Sum: 26d1b1df3265b877e143ec625abfd863519c2265
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/26d1b1df3265b877e143ec625abfd863519c2265
#     venv/lib/python3.9/site-packages/Flask_SQLAlchemy-2.5.1.dist-info/REQUESTED:
#       sha1Sum: da39a3ee5e6b4b0d3255bfef95601890afd80709
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da39a3ee5e6b4b0d3255bfef95601890afd80709
#     venv/lib/python3.9/site-packages/Flask_SQLAlchemy-2.5.1.dist-info/WHEEL:
#       sha1Sum: 407755edc93510d5f7556ecdd1e7cb42f9357d8f
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/407755edc93510d5f7556ecdd1e7cb42f9357d8f
#     venv/lib/python3.9/site-packages/Flask_SQLAlchemy-2.5.1.dist-info/top_level.txt:
#       sha1Sum: 1f052c35960bf223c478510bb61fa428bd14e5eb
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1f052c35960bf223c478510bb61fa428bd14e5eb
#     venv/lib/python3.9/site-packages/Flask_User-1.0.2.2.dist-info/AUTHORS.rst:
#       sha1Sum: 7e811fa09da752284c74cbe612a80b28c424223f
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/7e811fa09da752284c74cbe612a80b28c424223f
#     venv/lib/python3.9/site-packages/Flask_User-1.0.2.2.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Flask_User-1.0.2.2.dist-info/LICENSE.txt:
#       sha1Sum: 4be2d78e479e997c04caf5372598fc93ccc5d1ac
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/4be2d78e479e997c04caf5372598fc93ccc5d1ac
#     venv/lib/python3.9/site-packages/Flask_User-1.0.2.2.dist-info/METADATA:
#       sha1Sum: 4a927b868fe01d1c2c071c9e2e9ac268240abea5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/4a927b868fe01d1c2c071c9e2e9ac268240abea5
#     venv/lib/python3.9/site-packages/Flask_User-1.0.2.2.dist-info/RECORD:
#       sha1Sum: 26f4ae4713dd6522558a4b511d02056b1991d7ea
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/26f4ae4713dd6522558a4b511d02056b1991d7ea
#     venv/lib/python3.9/site-packages/Flask_User-1.0.2.2.dist-info/REQUESTED:
#       sha1Sum: da39a3ee5e6b4b0d3255bfef95601890afd80709
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da39a3ee5e6b4b0d3255bfef95601890afd80709
#     venv/lib/python3.9/site-packages/Flask_User-1.0.2.2.dist-info/WHEEL:
#       sha1Sum: 407755edc93510d5f7556ecdd1e7cb42f9357d8f
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/407755edc93510d5f7556ecdd1e7cb42f9357d8f
#     venv/lib/python3.9/site-packages/Flask_User-1.0.2.2.dist-info/top_level.txt:
#       sha1Sum: 1af3d8cac43bc8171f496825c6e5e9e8d4ae3185
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1af3d8cac43bc8171f496825c6e5e9e8d4ae3185
#     venv/lib/python3.9/site-packages/Flask_WTF-1.0.0.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Flask_WTF-1.0.0.dist-info/LICENSE.rst:
#       sha1Sum: 027639f137e5431d098343158ba4889a768f15f6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/027639f137e5431d098343158ba4889a768f15f6
#     venv/lib/python3.9/site-packages/Flask_WTF-1.0.0.dist-info/METADATA:
#       sha1Sum: 41f68036d6f00eeb2ea3f499931cd6fe5b16873b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/41f68036d6f00eeb2ea3f499931cd6fe5b16873b
#     venv/lib/python3.9/site-packages/Flask_WTF-1.0.0.dist-info/RECORD:
#       sha1Sum: 98e612d0bf8e2a3d01410b634831980fd824675c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/98e612d0bf8e2a3d01410b634831980fd824675c
#     venv/lib/python3.9/site-packages/Flask_WTF-1.0.0.dist-info/WHEEL:
#       sha1Sum: 40a2b8d62232140e022876da90b2c784970b715b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40a2b8d62232140e022876da90b2c784970b715b
#     venv/lib/python3.9/site-packages/Flask_WTF-1.0.0.dist-info/top_level.txt:
#       sha1Sum: 40f650bb7ad0522e18c4f9d9f20cbf678f0acb9e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40f650bb7ad0522e18c4f9d9f20cbf678f0acb9e
#     venv/lib/python3.9/site-packages/Jinja2-3.0.3.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Jinja2-3.0.3.dist-info/LICENSE.rst:
#       sha1Sum: c4dbdbc12926d4d52c9156e690640f372615c234
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c4dbdbc12926d4d52c9156e690640f372615c234
#     venv/lib/python3.9/site-packages/Jinja2-3.0.3.dist-info/METADATA:
#       sha1Sum: f5ce18a0e6835586124b3fb03599a8e22a0a399e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/f5ce18a0e6835586124b3fb03599a8e22a0a399e
#     venv/lib/python3.9/site-packages/Jinja2-3.0.3.dist-info/RECORD:
#       sha1Sum: eb4fe29ebadc3dd701d9351bf2a338cb9a93cab2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/eb4fe29ebadc3dd701d9351bf2a338cb9a93cab2
#     venv/lib/python3.9/site-packages/Jinja2-3.0.3.dist-info/WHEEL:
#       sha1Sum: 40a2b8d62232140e022876da90b2c784970b715b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40a2b8d62232140e022876da90b2c784970b715b
#     venv/lib/python3.9/site-packages/Jinja2-3.0.3.dist-info/entry_points.txt:
#       sha1Sum: aaeba3be7b056f2f9c5932c124f82e7cb71eac8b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/aaeba3be7b056f2f9c5932c124f82e7cb71eac8b
#     venv/lib/python3.9/site-packages/Jinja2-3.0.3.dist-info/top_level.txt:
#       sha1Sum: e28872899ce4cd3548d79e56190b681015fb40eb
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e28872899ce4cd3548d79e56190b681015fb40eb
#     venv/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/LICENSE.rst:
#       sha1Sum: e32a549b135c4b2b268107adc12d13cca2ca1e8c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e32a549b135c4b2b268107adc12d13cca2ca1e8c
#     venv/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/METADATA:
#       sha1Sum: 6e5fb15798fb0f4ac491a541634eaed9d46d76d5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6e5fb15798fb0f4ac491a541634eaed9d46d76d5
#     venv/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/RECORD:
#       sha1Sum: 0779b0bc53ca6f4f89c953084e30e201a44dcf45
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0779b0bc53ca6f4f89c953084e30e201a44dcf45
#     venv/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/WHEEL:
#       sha1Sum: b2f269f8c9d0248ff9a2c797ac4754bbb6864a70
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/b2f269f8c9d0248ff9a2c797ac4754bbb6864a70
#     venv/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/top_level.txt:
#       sha1Sum: f53e3e1c5d96f0c96145fd9477ea8dbd30aceb7b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/f53e3e1c5d96f0c96145fd9477ea8dbd30aceb7b
#     venv/lib/python3.9/site-packages/SQLAlchemy-1.4.27.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/SQLAlchemy-1.4.27.dist-info/LICENSE:
#       sha1Sum: eefb00d4476c9b701ca0d16d96de0df3cac2c35a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/eefb00d4476c9b701ca0d16d96de0df3cac2c35a
#     venv/lib/python3.9/site-packages/SQLAlchemy-1.4.27.dist-info/METADATA:
#       sha1Sum: 9c9d3318f5b61a6aa82b2480a1cb4e65e63e4990
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/9c9d3318f5b61a6aa82b2480a1cb4e65e63e4990
#     venv/lib/python3.9/site-packages/SQLAlchemy-1.4.27.dist-info/RECORD:
#       sha1Sum: 67966acdfff611f6823f8e02160badc7839ff1a6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/67966acdfff611f6823f8e02160badc7839ff1a6
#     venv/lib/python3.9/site-packages/SQLAlchemy-1.4.27.dist-info/REQUESTED:
#       sha1Sum: da39a3ee5e6b4b0d3255bfef95601890afd80709
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da39a3ee5e6b4b0d3255bfef95601890afd80709
#     venv/lib/python3.9/site-packages/SQLAlchemy-1.4.27.dist-info/WHEEL:
#       sha1Sum: 84336ab3358ad5713ceadf4a88d24922e68ac561
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/84336ab3358ad5713ceadf4a88d24922e68ac561
#     venv/lib/python3.9/site-packages/SQLAlchemy-1.4.27.dist-info/top_level.txt:
#       sha1Sum: 3fd6978f20cde2db85695a652400e45557b18cd7
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/3fd6978f20cde2db85695a652400e45557b18cd7
#     venv/lib/python3.9/site-packages/WTForms-3.0.0.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/WTForms-3.0.0.dist-info/LICENSE.rst:
#       sha1Sum: a6cce7d7b0a119c03043a88ffef3517a4b44a23f
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/a6cce7d7b0a119c03043a88ffef3517a4b44a23f
#     venv/lib/python3.9/site-packages/WTForms-3.0.0.dist-info/METADATA:
#       sha1Sum: 0223a2f87fffe362c12ce6d3afa40e7607636503
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0223a2f87fffe362c12ce6d3afa40e7607636503
#     venv/lib/python3.9/site-packages/WTForms-3.0.0.dist-info/RECORD:
#       sha1Sum: 814099b395a8f8b0ea1b4d386d12c101a238bec4
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/814099b395a8f8b0ea1b4d386d12c101a238bec4
#     venv/lib/python3.9/site-packages/WTForms-3.0.0.dist-info/WHEEL:
#       sha1Sum: 40a2b8d62232140e022876da90b2c784970b715b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40a2b8d62232140e022876da90b2c784970b715b
#     venv/lib/python3.9/site-packages/WTForms-3.0.0.dist-info/top_level.txt:
#       sha1Sum: e5501ad7ea1b4760dd9cab9d3175b0b696c5e003
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e5501ad7ea1b4760dd9cab9d3175b0b696c5e003
#     venv/lib/python3.9/site-packages/Werkzeug-2.0.2.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/Werkzeug-2.0.2.dist-info/LICENSE.rst:
#       sha1Sum: c4dbdbc12926d4d52c9156e690640f372615c234
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c4dbdbc12926d4d52c9156e690640f372615c234
#     venv/lib/python3.9/site-packages/Werkzeug-2.0.2.dist-info/METADATA:
#       sha1Sum: ffd8e87999044680b80aa58121451ee022678dc5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ffd8e87999044680b80aa58121451ee022678dc5
#     venv/lib/python3.9/site-packages/Werkzeug-2.0.2.dist-info/RECORD:
#       sha1Sum: fb36f676b047f51426b7cf94ddbdd0d2dd9cc0ff
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/fb36f676b047f51426b7cf94ddbdd0d2dd9cc0ff
#     venv/lib/python3.9/site-packages/Werkzeug-2.0.2.dist-info/WHEEL:
#       sha1Sum: 40a2b8d62232140e022876da90b2c784970b715b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40a2b8d62232140e022876da90b2c784970b715b
#     venv/lib/python3.9/site-packages/Werkzeug-2.0.2.dist-info/top_level.txt:
#       sha1Sum: 411cfb915a49186b3885431ce832fe61b41a4832
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/411cfb915a49186b3885431ce832fe61b41a4832
#     venv/lib/python3.9/site-packages/_cffi_backend.cpython-39-x86_64-linux-gnu.so:
#       sha1Sum: 2303ffc1f50d40a92382533ab4fddf93179ec8fe
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/2303ffc1f50d40a92382533ab4fddf93179ec8fe
#     venv/lib/python3.9/site-packages/_distutils_hack/__init__.py:
#       sha1Sum: 327d5e3fa25e4a0756cde35ee677035997c00f7e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/327d5e3fa25e4a0756cde35ee677035997c00f7e
#     venv/lib/python3.9/site-packages/_distutils_hack/override.py:
#       sha1Sum: 358f87c599947263e8adf079cb2131a522876af8
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/358f87c599947263e8adf079cb2131a522876af8
#     venv/lib/python3.9/site-packages/_virtualenv.pth:
#       sha1Sum: 6cebf22fc1dbd8f7d9492a12866a480cb8658c21
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6cebf22fc1dbd8f7d9492a12866a480cb8658c21
#     venv/lib/python3.9/site-packages/_virtualenv.py:
#       sha1Sum: 0940efa846da00a020bf2ae6fa222ef8616239c5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0940efa846da00a020bf2ae6fa222ef8616239c5
#     venv/lib/python3.9/site-packages/apiflask/__init__.py:
#       sha1Sum: 6a19fb358ff62a97dbe6589f688ff9ab11bd3c5e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6a19fb358ff62a97dbe6589f688ff9ab11bd3c5e
#     venv/lib/python3.9/site-packages/apiflask/app.py:
#       sha1Sum: 26877f694e54aa25224a33b085c7a59d1bcadac3
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/26877f694e54aa25224a33b085c7a59d1bcadac3
#     venv/lib/python3.9/site-packages/apiflask/blueprint.py:
#       sha1Sum: 195fd60b19c74407965e0d3d4b69a060eb721d4c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/195fd60b19c74407965e0d3d4b69a060eb721d4c
#     venv/lib/python3.9/site-packages/apiflask/commands.py:
#       sha1Sum: b8032ba48ceb4d224c0edc4654d3da2461f7b783
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/b8032ba48ceb4d224c0edc4654d3da2461f7b783
#     venv/lib/python3.9/site-packages/apiflask/decorators.py:
#       sha1Sum: 02366580324488bcf230f1eebd495fc55681b633
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/02366580324488bcf230f1eebd495fc55681b633
#     venv/lib/python3.9/site-packages/apiflask/exceptions.py:
#       sha1Sum: 8d07bd343a97de6cab0c46d13d1348937d0ec38a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/8d07bd343a97de6cab0c46d13d1348937d0ec38a
#     venv/lib/python3.9/site-packages/apiflask/fields.py:
#       sha1Sum: f9d8f5c7075e4663b8578e81dd382e2e6e72f07d
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/f9d8f5c7075e4663b8578e81dd382e2e6e72f07d
#     venv/lib/python3.9/site-packages/apiflask/helpers.py:
#       sha1Sum: 3cf52bb4c2639de6a0364a2905d77e5f0de7103d
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/3cf52bb4c2639de6a0364a2905d77e5f0de7103d
#     venv/lib/python3.9/site-packages/apiflask/openapi.py:
#       sha1Sum: eed1e64e5f4ec0f32fb3f12bf0aa8f41c26f447e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/eed1e64e5f4ec0f32fb3f12bf0aa8f41c26f447e
#     venv/lib/python3.9/site-packages/apiflask/py.typed:
#       sha1Sum: da39a3ee5e6b4b0d3255bfef95601890afd80709
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da39a3ee5e6b4b0d3255bfef95601890afd80709
#     venv/lib/python3.9/site-packages/apiflask/route.py:
#       sha1Sum: e524fd8d991a52f5469b05190a7ef032963fe1a4
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e524fd8d991a52f5469b05190a7ef032963fe1a4
#     venv/lib/python3.9/site-packages/apiflask/schemas.py:
#       sha1Sum: 33e04eec8c64834c847412c5f89fac779f2a6379
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/33e04eec8c64834c847412c5f89fac779f2a6379
#     venv/lib/python3.9/site-packages/apiflask/security.py:
#       sha1Sum: dfa736f180a68e5df15612c292bb6974f04266f6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/dfa736f180a68e5df15612c292bb6974f04266f6
#     venv/lib/python3.9/site-packages/apiflask/settings.py:
#       sha1Sum: cfbac1f2dd638e2596d7c23746aca6e1893941c8
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/cfbac1f2dd638e2596d7c23746aca6e1893941c8
#     venv/lib/python3.9/site-packages/apiflask/types.py:
#       sha1Sum: d45cb2649f74bb829064c912b70bf84985074fd1
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d45cb2649f74bb829064c912b70bf84985074fd1
#     venv/lib/python3.9/site-packages/apiflask/ui_templates.py:
#       sha1Sum: 73237de53f035ee2db7d915e79e7ee7cfac83eb6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/73237de53f035ee2db7d915e79e7ee7cfac83eb6
#     venv/lib/python3.9/site-packages/apiflask/validators.py:
#       sha1Sum: f30575c294931d29c4f6eb59ddd83cd97ea0b1de
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/f30575c294931d29c4f6eb59ddd83cd97ea0b1de
#     venv/lib/python3.9/site-packages/apispec-5.1.1.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/apispec-5.1.1.dist-info/LICENSE:
#       sha1Sum: 7ef22ee650017991d63c7b6a596506101d3a7b3c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/7ef22ee650017991d63c7b6a596506101d3a7b3c
#     venv/lib/python3.9/site-packages/apispec-5.1.1.dist-info/METADATA:
#       sha1Sum: 602c46893d1a519f3dc0efa5a39ef64a7f617268
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/602c46893d1a519f3dc0efa5a39ef64a7f617268
#     venv/lib/python3.9/site-packages/apispec-5.1.1.dist-info/RECORD:
#       sha1Sum: 81f7e581b70d2684b7c942eb55165a92072d0e6b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/81f7e581b70d2684b7c942eb55165a92072d0e6b
#     venv/lib/python3.9/site-packages/apispec-5.1.1.dist-info/WHEEL:
#       sha1Sum: 40a2b8d62232140e022876da90b2c784970b715b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40a2b8d62232140e022876da90b2c784970b715b
#     venv/lib/python3.9/site-packages/apispec-5.1.1.dist-info/top_level.txt:
#       sha1Sum: 19852ab2a959b9420331accd6ebb0fec0608ffe4
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/19852ab2a959b9420331accd6ebb0fec0608ffe4
#     venv/lib/python3.9/site-packages/apispec/__init__.py:
#       sha1Sum: 8e975e12e713d167f462b983cb35c145362bd1ba
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/8e975e12e713d167f462b983cb35c145362bd1ba
#     venv/lib/python3.9/site-packages/apispec/core.py:
#       sha1Sum: df93f1bba719cf76a139074472dd86efe0964d5a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/df93f1bba719cf76a139074472dd86efe0964d5a
#     venv/lib/python3.9/site-packages/apispec/exceptions.py:
#       sha1Sum: 5ede8405f1332f01df81edfd98a81c7cc54bcac7
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5ede8405f1332f01df81edfd98a81c7cc54bcac7
#     venv/lib/python3.9/site-packages/apispec/ext/__init__.py:
#       sha1Sum: da39a3ee5e6b4b0d3255bfef95601890afd80709
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da39a3ee5e6b4b0d3255bfef95601890afd80709
#     venv/lib/python3.9/site-packages/apispec/ext/marshmallow/__init__.py:
#       sha1Sum: 5f383bdb059017fa0af92f305e0542cc8d5c18c1
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5f383bdb059017fa0af92f305e0542cc8d5c18c1
#     venv/lib/python3.9/site-packages/apispec/ext/marshmallow/common.py:
#       sha1Sum: 70255d8757e2b3a24a1ebf5989e0208d49114c41
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/70255d8757e2b3a24a1ebf5989e0208d49114c41
#     venv/lib/python3.9/site-packages/apispec/ext/marshmallow/field_converter.py:
#       sha1Sum: a2b3861ab5b2d8359b19b92a4a83a39674fba59d
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/a2b3861ab5b2d8359b19b92a4a83a39674fba59d
#     venv/lib/python3.9/site-packages/apispec/ext/marshmallow/openapi.py:
#       sha1Sum: 7d57620af0d0e21b8b0169eaea76e71cf3eae559
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/7d57620af0d0e21b8b0169eaea76e71cf3eae559
#     venv/lib/python3.9/site-packages/apispec/ext/marshmallow/schema_resolver.py:
#       sha1Sum: 0da809a1dd04455dc7d95a6fc98b8aaf9acb36a6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0da809a1dd04455dc7d95a6fc98b8aaf9acb36a6
#     venv/lib/python3.9/site-packages/apispec/plugin.py:
#       sha1Sum: 083d58c63ec61ce3ad901f3d6d6f4aa721dce809
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/083d58c63ec61ce3ad901f3d6d6f4aa721dce809
#     venv/lib/python3.9/site-packages/apispec/utils.py:
#       sha1Sum: 105573b6834cb283a343108842c70acecffad02e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/105573b6834cb283a343108842c70acecffad02e
#     venv/lib/python3.9/site-packages/apispec/yaml_utils.py:
#       sha1Sum: 2eecb2b62eb4ffe601412132c9fc92cc1d32b88d
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/2eecb2b62eb4ffe601412132c9fc92cc1d32b88d
#     venv/lib/python3.9/site-packages/bcrypt-3.2.0.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/bcrypt-3.2.0.dist-info/LICENSE:
#       sha1Sum: 5feaf15b3fa7d2d226d811e5fcd49098a1ea520c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5feaf15b3fa7d2d226d811e5fcd49098a1ea520c
#     venv/lib/python3.9/site-packages/bcrypt-3.2.0.dist-info/METADATA:
#       sha1Sum: c683066975ad44cb0793fedf5d4be80105f2fef6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c683066975ad44cb0793fedf5d4be80105f2fef6
#     venv/lib/python3.9/site-packages/bcrypt-3.2.0.dist-info/RECORD:
#       sha1Sum: cd32620db24e50efe81b160ebe13c4456cb5de9d
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/cd32620db24e50efe81b160ebe13c4456cb5de9d
#     venv/lib/python3.9/site-packages/bcrypt-3.2.0.dist-info/REQUESTED:
#       sha1Sum: da39a3ee5e6b4b0d3255bfef95601890afd80709
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da39a3ee5e6b4b0d3255bfef95601890afd80709
#     venv/lib/python3.9/site-packages/bcrypt-3.2.0.dist-info/WHEEL:
#       sha1Sum: 3adafcb6b3dc13679117e7910cd1c278efdc8839
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/3adafcb6b3dc13679117e7910cd1c278efdc8839
#     venv/lib/python3.9/site-packages/bcrypt-3.2.0.dist-info/top_level.txt:
#       sha1Sum: bc153e397ecc01657e862c48be48e41884fd715a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/bc153e397ecc01657e862c48be48e41884fd715a
#     venv/lib/python3.9/site-packages/bcrypt/__about__.py:
#       sha1Sum: dff6a97b1182cf8c3916fecf3e188e4af198470d
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/dff6a97b1182cf8c3916fecf3e188e4af198470d
#     venv/lib/python3.9/site-packages/bcrypt/__init__.py:
#       sha1Sum: dfc1cb3457cc1540afea8ea22ae6979cc5bd32e4
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/dfc1cb3457cc1540afea8ea22ae6979cc5bd32e4
#     venv/lib/python3.9/site-packages/bcrypt/_bcrypt.abi3.so:
#       sha1Sum: 61225d5f683c1666edcc6477ea2862c962100df0
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/61225d5f683c1666edcc6477ea2862c962100df0
#     venv/lib/python3.9/site-packages/bcrypt/py.typed:
#       sha1Sum: da39a3ee5e6b4b0d3255bfef95601890afd80709
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da39a3ee5e6b4b0d3255bfef95601890afd80709
#     venv/lib/python3.9/site-packages/blinker-1.4.dist-info/AUTHORS:
#       sha1Sum: 40e2217e34cf01476714010654b4e751c0419ee5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/40e2217e34cf01476714010654b4e751c0419ee5
#     venv/lib/python3.9/site-packages/blinker-1.4.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/blinker-1.4.dist-info/LICENSE:
#       sha1Sum: 15f4d259a18581c81f42f3dd47da3f66e2a72e1c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/15f4d259a18581c81f42f3dd47da3f66e2a72e1c
#     venv/lib/python3.9/site-packages/blinker-1.4.dist-info/METADATA:
#       sha1Sum: 052bfba44de06a0603a801383f53190062509cc2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/052bfba44de06a0603a801383f53190062509cc2
#     venv/lib/python3.9/site-packages/blinker-1.4.dist-info/RECORD:
#       sha1Sum: 557aa60308f6ffdb6f4592f3628c7429ffebf48e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/557aa60308f6ffdb6f4592f3628c7429ffebf48e
#     venv/lib/python3.9/site-packages/blinker-1.4.dist-info/WHEEL:
#       sha1Sum: 249fdb01ad3e3f71356e33e1897d06f23cfb20c2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/249fdb01ad3e3f71356e33e1897d06f23cfb20c2
#     venv/lib/python3.9/site-packages/blinker-1.4.dist-info/top_level.txt:
#       sha1Sum: ddaa6e52a4d163e60311ec43afd56d5550c7616f
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ddaa6e52a4d163e60311ec43afd56d5550c7616f
#     venv/lib/python3.9/site-packages/blinker/__init__.py:
#       sha1Sum: f3a53296ea5e1c0f04c3dea28482019c0d513ca6
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/f3a53296ea5e1c0f04c3dea28482019c0d513ca6
#     venv/lib/python3.9/site-packages/blinker/_saferef.py:
#       sha1Sum: 105050ae2c92dc098d53c1a7c8db0635b10355e4
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/105050ae2c92dc098d53c1a7c8db0635b10355e4
#     venv/lib/python3.9/site-packages/blinker/_utilities.py:
#       sha1Sum: 7eb850373b6d75702c0f72d5cb5efea7448ad37c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/7eb850373b6d75702c0f72d5cb5efea7448ad37c
#     venv/lib/python3.9/site-packages/blinker/base.py:
#       sha1Sum: 82544fe5f1c08c20723bc140ed25a4359e8504e8
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/82544fe5f1c08c20723bc140ed25a4359e8504e8
#     venv/lib/python3.9/site-packages/cffi-1.15.0.dist-info/INSTALLER:
#       sha1Sum: d7a03141d5d6b1e88b6b59ef08b6681df212c599
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d7a03141d5d6b1e88b6b59ef08b6681df212c599
#     venv/lib/python3.9/site-packages/cffi-1.15.0.dist-info/LICENSE:
#       sha1Sum: 65e8b9015ffb0747c23370a3d3af2a796c64780e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/65e8b9015ffb0747c23370a3d3af2a796c64780e
#     venv/lib/python3.9/site-packages/cffi-1.15.0.dist-info/METADATA:
#       sha1Sum: 1e98d3ff92e07dc71195571d8d86e671df70f48e
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1e98d3ff92e07dc71195571d8d86e671df70f48e
#     venv/lib/python3.9/site-packages/cffi-1.15.0.dist-info/RECORD:
#       sha1Sum: 7b7a225a13b7b5ccb78882c9eff48655f4714072
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/7b7a225a13b7b5ccb78882c9eff48655f4714072
#     venv/lib/python3.9/site-packages/cffi-1.15.0.dist-info/WHEEL:
#       sha1Sum: 3fa733e90c734d47c234908ecf668788aa06c0ec
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/3fa733e90c734d47c234908ecf668788aa06c0ec
#     venv/lib/python3.9/site-packages/cffi-1.15.0.dist-info/entry_points.txt:
#       sha1Sum: 85585480c856eb45360935f59c8c24f519959f72
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/85585480c856eb45360935f59c8c24f519959f72
#     venv/lib/python3.9/site-packages/cffi-1.15.0.dist-info/top_level.txt:
#       sha1Sum: 5a38c6f6b4ba1cf98f2377db77f55a568089d94c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5a38c6f6b4ba1cf98f2377db77f55a568089d94c
#     venv/lib/python3.9/site-packages/cffi.libs/libffi-9c61262e.so.8.1.0:
#       sha1Sum: ce5934b77221780587822062668d691a001565d9
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ce5934b77221780587822062668d691a001565d9
#     venv/lib/python3.9/site-packages/cffi/__init__.py:
#       sha1Sum: 6bc95db02515815739b826e83feb3ab709d77e89
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6bc95db02515815739b826e83feb3ab709d77e89
#     venv/lib/python3.9/site-packages/cffi/_cffi_errors.h:
#       sha1Sum: d9e39b52a6ac381c482234ee5b50883c364f0422
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d9e39b52a6ac381c482234ee5b50883c364f0422
#     venv/lib/python3.9/site-packages/cffi/_cffi_include.h:
#       sha1Sum: 4a86476eb7298469702184888211a84d65d2133a
# ...
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/cab86449d250859f588c6f44d21f29d223745d8e
#     venv/lib/python3.9/site-packages/wtforms/locale/cy/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 16a307b981a678f102a2a58abd86d38f9caddc94
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/16a307b981a678f102a2a58abd86d38f9caddc94
#     venv/lib/python3.9/site-packages/wtforms/locale/cy/LC_MESSAGES/wtforms.po:
#       sha1Sum: 0fd0348195b04c6b0bfdcaaf19b8117f2b191a4a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0fd0348195b04c6b0bfdcaaf19b8117f2b191a4a
#     venv/lib/python3.9/site-packages/wtforms/locale/de/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 6020f914e1fd069f4967d8669bcd078c3767bd2b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6020f914e1fd069f4967d8669bcd078c3767bd2b
#     venv/lib/python3.9/site-packages/wtforms/locale/de/LC_MESSAGES/wtforms.po:
#       sha1Sum: da08ba0aa483727e88e5af94fa9bb45570fbf2e1
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/da08ba0aa483727e88e5af94fa9bb45570fbf2e1
#     venv/lib/python3.9/site-packages/wtforms/locale/de_CH/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 222b07bb16a775754f41758528b2937ecff1f572
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/222b07bb16a775754f41758528b2937ecff1f572
#     venv/lib/python3.9/site-packages/wtforms/locale/de_CH/LC_MESSAGES/wtforms.po:
#       sha1Sum: 6b74e5aae45121462b463d800ec37dc44f264487
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/6b74e5aae45121462b463d800ec37dc44f264487
#     venv/lib/python3.9/site-packages/wtforms/locale/el/LC_MESSAGES/wtforms.mo:
#       sha1Sum: ce638c4269ce382efa63be14896abd5c3ea44993
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ce638c4269ce382efa63be14896abd5c3ea44993
#     venv/lib/python3.9/site-packages/wtforms/locale/el/LC_MESSAGES/wtforms.po:
#       sha1Sum: 01333172b071d2588b05881177552427bc1d686c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/01333172b071d2588b05881177552427bc1d686c
#     venv/lib/python3.9/site-packages/wtforms/locale/en/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 2bbe281f41d91c8ec0e2082cf5b3cbec1dc945de
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/2bbe281f41d91c8ec0e2082cf5b3cbec1dc945de
#     venv/lib/python3.9/site-packages/wtforms/locale/en/LC_MESSAGES/wtforms.po:
#       sha1Sum: f31bc11ff8cbf791825b713f84f590b3af434abc
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/f31bc11ff8cbf791825b713f84f590b3af434abc
#     venv/lib/python3.9/site-packages/wtforms/locale/es/LC_MESSAGES/wtforms.mo:
#       sha1Sum: d766aacf76c92790d0480a256e98b96662e2d5db
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/d766aacf76c92790d0480a256e98b96662e2d5db
#     venv/lib/python3.9/site-packages/wtforms/locale/es/LC_MESSAGES/wtforms.po:
#       sha1Sum: 05db70ac329e91b27734196efcf12a51d0404003
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/05db70ac329e91b27734196efcf12a51d0404003
#     venv/lib/python3.9/site-packages/wtforms/locale/et/LC_MESSAGES/wtforms.mo:
#       sha1Sum: bcfa5a2a2aebec6458385da3d34bccc216eb407a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/bcfa5a2a2aebec6458385da3d34bccc216eb407a
#     venv/lib/python3.9/site-packages/wtforms/locale/et/LC_MESSAGES/wtforms.po:
#       sha1Sum: 651a0d7590320b6f1163f185f1690236c790c581
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/651a0d7590320b6f1163f185f1690236c790c581
#     venv/lib/python3.9/site-packages/wtforms/locale/fa/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 15f93ef8616377452366ccddfdc9c7fa062d03b1
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/15f93ef8616377452366ccddfdc9c7fa062d03b1
#     venv/lib/python3.9/site-packages/wtforms/locale/fa/LC_MESSAGES/wtforms.po:
#       sha1Sum: c8316b69ea051ef79df32e30c1ce01a3e155c13a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c8316b69ea051ef79df32e30c1ce01a3e155c13a
#     venv/lib/python3.9/site-packages/wtforms/locale/fi/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 5e94d2fb6840a4bbec8a366296369fb01d1462db
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5e94d2fb6840a4bbec8a366296369fb01d1462db
#     venv/lib/python3.9/site-packages/wtforms/locale/fi/LC_MESSAGES/wtforms.po:
#       sha1Sum: 78b807506b8950e91e15f307541ae53d9c402e53
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/78b807506b8950e91e15f307541ae53d9c402e53
#     venv/lib/python3.9/site-packages/wtforms/locale/fr/LC_MESSAGES/wtforms.mo:
#       sha1Sum: ba5d749e30824c097fffc2cf070d442fba061351
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ba5d749e30824c097fffc2cf070d442fba061351
#     venv/lib/python3.9/site-packages/wtforms/locale/fr/LC_MESSAGES/wtforms.po:
#       sha1Sum: 1bd24ad340f3187a3e52bf694d550fffc1d904fd
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1bd24ad340f3187a3e52bf694d550fffc1d904fd
#     venv/lib/python3.9/site-packages/wtforms/locale/he/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 0c1c94010aa0b5b1f5615927a855b2d2ad1d9085
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0c1c94010aa0b5b1f5615927a855b2d2ad1d9085
#     venv/lib/python3.9/site-packages/wtforms/locale/he/LC_MESSAGES/wtforms.po:
#       sha1Sum: 444186306516f13dff05d1fb2e8d31fbe2745298
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/444186306516f13dff05d1fb2e8d31fbe2745298
#     venv/lib/python3.9/site-packages/wtforms/locale/hu/LC_MESSAGES/wtforms.mo:
#       sha1Sum: ff4160f4da236addb45120d25be0166c5eb554af
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/ff4160f4da236addb45120d25be0166c5eb554af
#     venv/lib/python3.9/site-packages/wtforms/locale/hu/LC_MESSAGES/wtforms.po:
#       sha1Sum: 546a7f3c5aacebafa6777752df160e02735bcd9a
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/546a7f3c5aacebafa6777752df160e02735bcd9a
#     venv/lib/python3.9/site-packages/wtforms/locale/it/LC_MESSAGES/wtforms.mo:
#       sha1Sum: acb1c68ec007f274aee83db96f4eb3d6d555ed54
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/acb1c68ec007f274aee83db96f4eb3d6d555ed54
#     venv/lib/python3.9/site-packages/wtforms/locale/it/LC_MESSAGES/wtforms.po:
#       sha1Sum: 0ddafcaff3cee047d4dca466067952cc602f5ed5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0ddafcaff3cee047d4dca466067952cc602f5ed5
#     venv/lib/python3.9/site-packages/wtforms/locale/ja/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 5f59ffa0c1c516eb09ba71bf7afd0c006aba250b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5f59ffa0c1c516eb09ba71bf7afd0c006aba250b
#     venv/lib/python3.9/site-packages/wtforms/locale/ja/LC_MESSAGES/wtforms.po:
#       sha1Sum: c6ab082fb0725db2c0f22f5547a42e44f3a40074
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c6ab082fb0725db2c0f22f5547a42e44f3a40074
#     venv/lib/python3.9/site-packages/wtforms/locale/ko/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 833ff0551ee13905779d72bfd1c4730035c2c767
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/833ff0551ee13905779d72bfd1c4730035c2c767
#     venv/lib/python3.9/site-packages/wtforms/locale/ko/LC_MESSAGES/wtforms.po:
#       sha1Sum: 95946cc52eefdaf566eb5206e3ccc965a4ffe1d9
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/95946cc52eefdaf566eb5206e3ccc965a4ffe1d9
#     venv/lib/python3.9/site-packages/wtforms/locale/nb/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 5ff28ee6757e1bc7668807e0b30a8a6135573df8
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/5ff28ee6757e1bc7668807e0b30a8a6135573df8
#     venv/lib/python3.9/site-packages/wtforms/locale/nb/LC_MESSAGES/wtforms.po:
#       sha1Sum: e53340318eabd8107963946bbedbf3b59c2ff2bf
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e53340318eabd8107963946bbedbf3b59c2ff2bf
#     venv/lib/python3.9/site-packages/wtforms/locale/nl/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 3aaa44370328f0bfc8a1f88ab0aa2f80aed72478
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/3aaa44370328f0bfc8a1f88ab0aa2f80aed72478
#     venv/lib/python3.9/site-packages/wtforms/locale/nl/LC_MESSAGES/wtforms.po:
#       sha1Sum: c873b1e314acfae5da17ae41f6061ea699d0e144
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c873b1e314acfae5da17ae41f6061ea699d0e144
#     venv/lib/python3.9/site-packages/wtforms/locale/pl/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 0e9dab1e6788f94e9619554222083d188e51afef
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/0e9dab1e6788f94e9619554222083d188e51afef
#     venv/lib/python3.9/site-packages/wtforms/locale/pl/LC_MESSAGES/wtforms.po:
#       sha1Sum: 655a8f6ec5371b7bb7a2e50050ee628fbfaad6ca
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/655a8f6ec5371b7bb7a2e50050ee628fbfaad6ca
#     venv/lib/python3.9/site-packages/wtforms/locale/pt/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 7d6661d6d17924de97d6fde874794ff49c6586de
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/7d6661d6d17924de97d6fde874794ff49c6586de
#     venv/lib/python3.9/site-packages/wtforms/locale/pt/LC_MESSAGES/wtforms.po:
#       sha1Sum: 3fbe9735b43d6ac7ac215bb90cc66c696fa65afa
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/3fbe9735b43d6ac7ac215bb90cc66c696fa65afa
#     venv/lib/python3.9/site-packages/wtforms/locale/ru/LC_MESSAGES/wtforms.mo:
#       sha1Sum: a02baaa333a4c3fd5d945412e51486fe5945b1f0
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/a02baaa333a4c3fd5d945412e51486fe5945b1f0
#     venv/lib/python3.9/site-packages/wtforms/locale/ru/LC_MESSAGES/wtforms.po:
#       sha1Sum: cd39a9cf6e383c31f875c32ec828521384ce3522
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/cd39a9cf6e383c31f875c32ec828521384ce3522
#     venv/lib/python3.9/site-packages/wtforms/locale/sk/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 936f963d654e3dcd5522b3b5fac7f87cfd14bf0c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/936f963d654e3dcd5522b3b5fac7f87cfd14bf0c
#     venv/lib/python3.9/site-packages/wtforms/locale/sk/LC_MESSAGES/wtforms.po:
#       sha1Sum: 49fe1afcfcefe70c93748aedbce39ce4ce3b09a2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/49fe1afcfcefe70c93748aedbce39ce4ce3b09a2
#     venv/lib/python3.9/site-packages/wtforms/locale/sv/LC_MESSAGES/wtforms.mo:
#       sha1Sum: c82ffb3bd69e6bb1c283c08542902725d185df6c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c82ffb3bd69e6bb1c283c08542902725d185df6c
#     venv/lib/python3.9/site-packages/wtforms/locale/sv/LC_MESSAGES/wtforms.po:
#       sha1Sum: 2d83c1a68273b88047e1da4dcb37d62d5b5fe01d
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/2d83c1a68273b88047e1da4dcb37d62d5b5fe01d
#     venv/lib/python3.9/site-packages/wtforms/locale/tr/LC_MESSAGES/wtforms.mo:
#       sha1Sum: e79e78f0ecbf041838880652dfe813953cf8531f
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/e79e78f0ecbf041838880652dfe813953cf8531f
#     venv/lib/python3.9/site-packages/wtforms/locale/tr/LC_MESSAGES/wtforms.po:
#       sha1Sum: c4146067275d8fc31c501b9034fe2d2421dd9d1c
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c4146067275d8fc31c501b9034fe2d2421dd9d1c
#     venv/lib/python3.9/site-packages/wtforms/locale/uk/LC_MESSAGES/wtforms.mo:
#       sha1Sum: c275103fe293af4cbc1431da1672f980914b3d8b
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c275103fe293af4cbc1431da1672f980914b3d8b
#     venv/lib/python3.9/site-packages/wtforms/locale/uk/LC_MESSAGES/wtforms.po:
#       sha1Sum: 73207ff0f07bd833a5739dccae6adb2e205dd7a2
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/73207ff0f07bd833a5739dccae6adb2e205dd7a2
#     venv/lib/python3.9/site-packages/wtforms/locale/wtforms.pot:
#       sha1Sum: c06c3e3a50020ef510b099fc073eaa025e38d6f3
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/c06c3e3a50020ef510b099fc073eaa025e38d6f3
#     venv/lib/python3.9/site-packages/wtforms/locale/zh/LC_MESSAGES/wtforms.mo:
#       sha1Sum: b1006d6f6951d290a89ef921a02b525f4e648947
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/b1006d6f6951d290a89ef921a02b525f4e648947
#     venv/lib/python3.9/site-packages/wtforms/locale/zh/LC_MESSAGES/wtforms.po:
#       sha1Sum: 9f8455c790603fba29737ae29604d479ef5f4cbd
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/9f8455c790603fba29737ae29604d479ef5f4cbd
#     venv/lib/python3.9/site-packages/wtforms/locale/zh_TW/LC_MESSAGES/wtforms.mo:
#       sha1Sum: 92f4262b2580aee336c656b8386867504777a930
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/92f4262b2580aee336c656b8386867504777a930
#     venv/lib/python3.9/site-packages/wtforms/locale/zh_TW/LC_MESSAGES/wtforms.po:
#       sha1Sum: 2affcee2ac2ffe74ae05565b8baefc2d0a2f85a4
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/2affcee2ac2ffe74ae05565b8baefc2d0a2f85a4
#     venv/lib/python3.9/site-packages/wtforms/meta.py:
#       sha1Sum: 06e58bacf982244af6e8df43069f439112c1e2c5
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/06e58bacf982244af6e8df43069f439112c1e2c5
#     venv/lib/python3.9/site-packages/wtforms/utils.py:
#       sha1Sum: 109b91bbd5e7faa49fb6a9fde51ceda45fb298da
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/109b91bbd5e7faa49fb6a9fde51ceda45fb298da
#     venv/lib/python3.9/site-packages/wtforms/validators.py:
#       sha1Sum: b89434c87ca86f30d1f95c01cf75dd8ec9911835
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/b89434c87ca86f30d1f95c01cf75dd8ec9911835
#     venv/lib/python3.9/site-packages/wtforms/widgets/__init__.py:
#       sha1Sum: f2145f7ec274e94416a431897786774dd6f6b876
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/f2145f7ec274e94416a431897786774dd6f6b876
#     venv/lib/python3.9/site-packages/wtforms/widgets/core.py:
#       sha1Sum: aeadcd251bee9b98678cbb5b95134b53c55d71b0
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/aeadcd251bee9b98678cbb5b95134b53c55d71b0
#     venv/pyvenv.cfg:
#       sha1Sum: 1f2531a6f899fdca713074d4d2bdc63ae1334efa
#       sourceUrl: https://storage.googleapis.com/staging.tercera-generacion.appspot.com/1f2531a6f899fdca713074d4d2bdc63ae1334efa
# diskUsageBytes: '111443855'
# env: standard
# handlers:
# - authFailAction: AUTH_FAIL_ACTION_REDIRECT
#   login: LOGIN_OPTIONAL
#   script:
#     scriptPath: auto
#   securityLevel: SECURE_OPTIONAL
#   urlRegex: .*
# id: 20211124t182948
# instanceClass: F1
# name: apps/tercera-generacion/services/default/versions/20211124t182948
# network: {}
# runtime: python39
# runtimeChannel: default
# servingStatus: SERVING
# threadsafe: true
# versionUrl: https://20211124t182948-dot-tercera-generacion.appspot.com
# : 1

# %%
gcloud app versions stop 20211122t191234 --quiet
# Out:
# Stopping the following versions:
#  - tercera-generacion/default/20211122t191234
# Stopping [tercera-generacion/default/20211122t191234]...failed.
# ERROR: (gcloud.app.versions.stop) INVALID_ARGUMENT: serving status cannot be changed for Automatic Scaling versions
# : 1

# %%
gcloud app versions start 20211122t191234

# %% [markdown]
# ## Escalado de instancias.
#
# *App Engine* permite definir instancias de *VM* que puedan procesar los requerimientos de cómputo de la aplicación a partir de ciertas condiciones.
#
# Dichas condiciones son descritas en el *script* ```apt.yaml```.
#
# https://cloud.google.com/appengine/docs/standard/python3/how-instances-are-managed

# %% [markdown]
# ### Clases de instancias.
#
# La opción ```instance_class``` permite definir el tipo de instancia que utilizará la aplicación.
#
# ```
# instance_class:<tipo>
# ```
#
#
# Las clase de instancia por defecto es ```F1```.
#
# https://cloud.google.com/appengine/docs/standard/python3/config/appref#instance_class

# %% [markdown]
# * Instancias residentes cuando se define unn número fijo de instancias.
# * Instancias dinámicas cuando escalan con base en la carga.

# %% [markdown]
# ### Escalado manual.
#
# Añadir al archivo ```app.yaml``` el parámetro ```manual_scaling```
#
# ```
# manual_scaling:
#   instances: <número>
# ```

# %% [markdown]
# ### Escalado básico.
#
# * ```max_instances```
# * ```idle-timeout``` ```m``` en minutos.
#
# ```
# basic_scaling:
#   max_instances: <número máximo>
#   idle_timeout: <tiempo>m
# ```

# %% [markdown]
# ### Escalado dinámico.
#
# Añadir al archivo ```app.yaml``` la sección ```automatic_scaling```
#
# * ```target_cpu_utilization``` máximo uso de CPU antes de crear una nueva instancia.
# * ```target_throughput_utilization``` número máximo de peticiones concurrentes 0.5 a 0.95
# * ```max_concurrent_requests``` número máximo de petciones en una instancia. 10 por defecto, máximo 80.
# * ```max_instances```
# * ```min_instances```
# * ```max_pending_latency```
# * ```min_pending_latency```
#
# ```
# automatic_scaling:
#   target_cpu_utilization: <objetivo de CPU>
#   min_instances: <número mínimo de instancias>
#   max_instances: <número máximo de instancias>
#   min_pending_latency: <tiempo mínimo de latencia>ms
#   max_pending_latency: <tiempo máximo de latencia>ms
#   max_concurrent_requests: <número máximo de peticiones concurrentes>
# ```

# %% [markdown]
# ### Distribución de tráfico.

# %% [markdown]
# * Dirección IP.
# * Cookie HTTP.
# * Selección aleatoria.

# %% [markdown]
# ## Gestión de tráfico entre versiones.

# %% [markdown]
# ### Migrar tráfico.
#
# https://cloud.google.com/appengine/docs/standard/python3/migrating-traffic

# %% [markdown]
# ### Dividir tráfico.
#
# https://cloud.google.com/appengine/docs/standard/python3/migrating-traffic

# %% [markdown]
# ```
# gcloud app services set-traffic <servicio> --splits v1=.4,v2=.6
# ```
#
# * ```--m̀igrate```
# * ```--split-by```

# %%
gcloud app services set-traffic default --splits 20211124t182948=.4,20211124t171353=.6 --quiet
# Out:
# Setting the following traffic allocation:
#  - tercera-generacion/default/20211124t182948: 0.4
#  - tercera-generacion/default/20211124t171353: 0.6
# NOTE: Splitting traffic by ip.
# Any other versions of the specified service will receive zero traffic.
# Setting traffic split for service [default]...done.
# : 1

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2021.</p>
